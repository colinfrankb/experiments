# %%
from sshtunnel import SSHTunnelForwarder
import sshtunnel
import psycopg2
import os
import pandas as pd

# %%
# Please create a ssh keypair (without a passphrase) and request access from Colin 
# to the ci3.sweepsouth.io server

# Establish SSh connection
server = sshtunnel.open_tunnel(
    ("ci3.sweepsouth.io" , 22),
    ssh_username="prathikshasingh",
    ssh_pkey="/Users/prathikshasingh/.ssh/id_rsa",
    remote_bind_address=("connect-qa-master-do-user-4001697-0.db.ondigitalocean.com", 25060),
    local_bind_address=('0.0.0.0', 5432)
)

# Start connection
server.start()
print(server.local_bind_port)
print("tunnel opened. input any value to close")
# Out:
# 5432
# tunnel opened. input any value to close

# %%
# Fetch data
conn = psycopg2.connect(
    database="sweepsouth_connect",
    user="",
    host='localhost',
    port=5432,
    password="")

cur = conn.cursor()

cur.execute("select * from service_provider limit 100;")
data = cur.fetchall()
# print(data)
df = pd.DataFrame(data)
print(df)

# Data can be written to a file/interacted with directly in a dataframe.
# Out:
#      0                  1               2   \
# 0   154             Kelvin   +254701572517
# 1   259        Anne Davids    +27727013836
# 2   260  Hadrian Hasselhof    +27615870397
# 3   217        Just Fix It    +27820489406
# 4   261     Evelyn Cameron    +27831610067
# ..  ...                ...             ...
# 95  368     Lambda Cameron    +27713874963
# 96  369     Lindsey Friggs    +27712571365
# 97  370    Patrick Cameron    +27814753148
# 98  271   Andrew Hemsworth    +27724321452
# 99  209   Sammy’s Painting  +2347025689368
#
#                                                    3   \
# 0   provider_pics/2aa8319f-4ef5-4c95-be8e-4a044174...
# 1   provider_pics/27e8f3e6-b73d-47d6-8a58-b52b5e6e...
# 2   provider_pics/1507ec2b-7b96-41f9-98c1-86df51fd...
# 3   provider_pics/0bffec07-af35-4378-ae7d-d62919ce...
# 4   provider_pics/35d0ed9f-6fdd-4c35-887c-b8f13b6f...
# ..                                                ...
# 95  provider_pics/180a73f3-39cb-4f92-be1f-f75f134f...
# ...

# %%
# Close SSH connection

server.stop()
